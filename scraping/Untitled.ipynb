# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.fotocasa.es/es/comprar/pisos/madrid-capital/todas-las-zonas/l"

# %%
resp = requests.get(url)

# %%
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# '<!doctype html><html lang="es"><head><meta charset="utf-8"><!-- %CRITICALCSS% --><link rel="preconnect" href="https://frtassets.fotocasa.es"><link rel="preconnect" href="https://static.fotocasa.es"><link rel="preconnect" href="https://static.inmofactory.com"><link rel="preconnect" href="https://tags.tiqcdn.com" crossorigin><link rel="preconnect" href="https://logx.optimizely.com" crossorigin><link rel="preconnect" href="https://sb.scorecardresearch.com"><link as="script" rel="preload" href="https://frtassets.fotocasa.es/SearchPage.379c81af.js" /><link as="script" rel="preload" href="https://frtassets.fotocasa.es/main.e5988f39.js" /><link as="script" importance="low" rel="preload" href="https://frtassets.fotocasa.es/external-scripts/analytics-pro.js"><script defer="defer" src="https://frtassets.fotocasa.es/external-scripts/analytics-pro.js"></script><script>!function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&co
# ...
